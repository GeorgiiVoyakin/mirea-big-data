# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import matplotlib.patches as mpatches

# %%
df = pd.read_csv("insurance.csv")

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.hist(figsize=(6, 6), edgecolor='black')
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'bmi'}>],
#        [<AxesSubplot:title={'center':'children'}>,
#         <AxesSubplot:title={'center':'charges'}>]], dtype=object)

# %% [markdown]
# Найти меры центральной тенденции и меры разброса для индекса массы тела (bmi) и расходов (charges).
# Отобразить результаты в виде текста и на гистограммах (3 вертикальные линии).
# Добавить легенду на графики. Сделать выводы.

# %%
mean = np.mean(df['bmi'])
mode = sts.mode(df['bmi'])
median = np.median(df['bmi'])

# %%
print(f'Среднее = {mean:.3f}')
print(f'Мода = {mode.mode[0]}')
print(f'Медиана = {median}')
# Out:
# Среднее = 30.663
# Мода = 32.3
# Медиана = 30.4

# %%
standard_deviation = df['bmi'].std()
rng = df['bmi'].max() - df['bmi'].min()
q1 = np.percentile(df['bmi'], 25 , interpolation = 'midpoint')
q3 = np.percentile(df['bmi'], 75 , interpolation = 'midpoint' )
iqr1 = q3 - q1
iqr2 = sts.iqr(df['bmi'], interpolation = 'midpoint' )
print('Стандартное отклонение: {:.3f}'.format(standard_deviation))
print('Размах: ', rng)
print('Межквартильный размах через numpy: {:.3f}'.format(iqr1))
print('Межквартильный размах через scipy: {:.3f}'.format(iqr2))
# Out:
# Стандартное отклонение: 6.098
# Размах:  37.17
# Межквартильный размах через numpy: 8.385
# Межквартильный размах через scipy: 8.385

# %%
df['bmi'].hist(edgecolor='black')
plt.xlabel('BMI', fontsize=12)
plt.vlines(x=[mean], ymin=0, ymax=330, color='red')
plt.vlines(x=[mode.mode[0]], ymin=0, ymax=330, color='yellow')
plt.vlines(x=[median], ymin=0, ymax=330, color='green')

red_patch = mpatches.Patch(color='red', label='Mean')
yellow_patch = mpatches.Patch(color='yellow', label='Mode')
green_patch = mpatches.Patch(color='green', label='Median')

plt.legend(handles=[red_patch, yellow_patch, green_patch])

# %%
mean = np.mean(df['charges'])
mode = sts.mode(df['charges'])
median = np.median(df['charges'])

# %%
print(f'Среднее = {mean:.3f}')
print(f'Мода = {mode.mode[0]}')
print(f'Медиана = {median}')
# Out:
# Среднее = 13270.422
# Мода = 1639.5631
# Медиана = 9382.033

# %%
standard_deviation = df['charges'].std()
rng = df['charges'].max() - df['charges'].min()
q1 = np.percentile(df['charges'], 25 , interpolation = 'midpoint')
q3 = np.percentile(df['charges'], 75 , interpolation = 'midpoint' )
iqr1 = q3 - q1
iqr2 = sts.iqr(df['charges'], interpolation = 'midpoint' )
print('Стандартное отклонение: {:.3f}'.format(standard_deviation))
print('Размах: {:.3f}'.format(rng))
print('Межквартильный размах через numpy: {:.3f}'.format(iqr1))
print('Межквартильный размах через scipy: {:.3f}'.format(iqr2))
# Out:
# Стандартное отклонение: 12110.011
# Размах: 62648.554
# Межквартильный размах через numpy: 11879.801
# Межквартильный размах через scipy: 11879.801

# %%
df['charges'].hist(edgecolor='black')

plt.xlabel('Charges', fontsize=12)
plt.vlines(x=[mean], ymin=0, ymax=550, color='red')
plt.vlines(x=[mode.mode[0]], ymin=0, ymax=550, color='yellow')
plt.vlines(x=[median], ymin=0, ymax=550, color='green')

red_patch = mpatches.Patch(color='red', label='Mean')
yellow_patch = mpatches.Patch(color='yellow', label='Mode')
green_patch = mpatches.Patch(color='green', label='Median')

plt.legend(handles=[red_patch, yellow_patch, green_patch])

# %% [markdown]
# Построить box-plot для числовых показателей. Названия графиков должны соответствовать названиям признаков.

# %%
plt.boxplot(df['age'])
plt.title('age')
# Out:
# Text(0.5, 1.0, 'age')

# %%
plt.boxplot(df['bmi'])
plt.title('bmi')
# Out:
# Text(0.5, 1.0, 'bmi')

# %%
plt.boxplot(df['children'])
plt.title('children')
# Out:
# Text(0.5, 1.0, 'children')

# %%
plt.boxplot(df['charges'])
plt.title('charges')
# Out:
# Text(0.5, 1.0, 'charges')
